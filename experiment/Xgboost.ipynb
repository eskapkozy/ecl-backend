# %%
import numpy as np
import pandas as frame

import importlib

import pandas as pd

import src.PDcomponent.run.xgboostrun as Xgboost
importlib.reload(Xgboost)

from src.PDcomponent.run.xgboostrun import XGBoostRun
from src.PDcomponent.pipelines.pdFeaturePipeline import PDFeaturePipeline

# %% [markdown]
# # Get Data

# %%
orig = frame.read_csv('/data/working/origination_v02.csv')
# Out:
# /var/folders/gy/2mbpv0kx5jz22fry28cqlnkc0000gn/T/ipykernel_16746/3542022219.py:1: DtypeWarning: Columns (25,26,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   orig = frame.read_csv('/Users/macbookpro/platform/Backend/data/working/origination_v02.csv')

# %%
hist  = frame.read_csv('/data/working/hist_12m.csv')
# Out:
# /var/folders/gy/2mbpv0kx5jz22fry28cqlnkc0000gn/T/ipykernel_16746/2861163649.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   hist  = frame.read_csv('/Users/macbookpro/platform/Backend/data/working/hist_12m.csv')

# %%
pipeline = PDFeaturePipeline(window_months=12, woe_config={"iv_threshold": 0.01, "metric": "woe"})
X,y = pipeline.build(hist, orig)
# Out:
# Copy DataFrame     : 8.1s
# Cast DPD           : 8.4s
# Groupby            : 0.0s
# Colonnes de travail: 12.0s

# %%
X_train = pd.read_csv('/data/processed/x_train.csv', sep=',')
y_train = pd.read_csv('/data/processed/y_train.csv', sep=',').squeeze()
X_val = pd.read_csv('/data/processed/x_val.csv', sep=',')
y_val = pd.read_csv('/data/processed/y_val.csv', sep=',').squeeze()

# %%
X_test = pd.read_csv('/data/processed/x_test.csv', sep=',')
y_test = pd.read_csv('/data/processed/y_test.csv', sep=',').squeeze()

# %% [markdown]
# # Config

# %%
config_path = '/configs/ressources/xgboost_train.yaml'

# %% [markdown]
# # Run

# %% [markdown]
# train

# %%
train_map = {'x_train':X_train, 'y_train':y_train}
val_map = {'x_val':X_val, 'y_val':y_val}

# %%
run = XGBoostRun(train_map = train_map, val_map = val_map, config_path = config_path)

# %%
run.run()
# Out:
# 🏃 View run Xgboost Train at: http://localhost:5000/#/experiments/1/runs/abf0cae5d9204f538a13385eabfee120
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %% [markdown]
# test
