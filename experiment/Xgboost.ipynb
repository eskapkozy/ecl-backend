# %%
import numpy as np
import pandas as frame

import importlib

import pandas as pd

import src.PDcomponent.run.xgboostrun as Xgboost
importlib.reload(Xgboost)

from src.PDcomponent.run.xgboostrun import XGBoostRun
from src.PDcomponent.pipelines.pdFeaturePipeline import PDFeaturePipeline

# %% [markdown]
# # Get Data

# %%
orig = frame.read_csv('/Users/macbookpro/platform/Backend/data/working/origination_v02.csv')
# Out:
# /var/folders/gy/2mbpv0kx5jz22fry28cqlnkc0000gn/T/ipykernel_80445/3542022219.py:1: DtypeWarning: Columns (25,26,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   orig = frame.read_csv('/Users/macbookpro/platform/Backend/data/working/origination_v02.csv')

# %%
hist  = frame.read_csv('/Users/macbookpro/platform/Backend/data/working/hist_12m.csv')
# Out:
# /var/folders/gy/2mbpv0kx5jz22fry28cqlnkc0000gn/T/ipykernel_80445/2861163649.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   hist  = frame.read_csv('/Users/macbookpro/platform/Backend/data/working/hist_12m.csv')

# %%
##pipeline = PDFeaturePipeline(window_months=12, woe_config={"iv_threshold": 0.01, "metric": "woe"})
#X,y = pipeline.build(hist, orig)

# %%
X_train = pd.read_csv('/Users/macbookpro/platform/Backend/data/processed/x_train.csv', sep=',')
y_train = pd.read_csv('/Users/macbookpro/platform/Backend/data/processed/y_train.csv', sep=',').squeeze()
X_val = pd.read_csv('/Users/macbookpro/platform/Backend/data/processed/x_val.csv', sep=',')
y_val = pd.read_csv('/Users/macbookpro/platform/Backend/data/processed/y_val.csv', sep=',').squeeze()

# %%
X_test = pd.read_csv('/Users/macbookpro/platform/Backend/data/processed/x_test.csv', sep=',')
y_test = pd.read_csv('/Users/macbookpro/platform/Backend/data/processed/y_test.csv', sep=',').squeeze()

# %% [markdown]
# # Config

# %%
config_path = '/Users/macbookpro/platform/Backend/configs/ressources/xgboost_train.yaml'
config_path_test ="/Users/macbookpro/platform/Backend/configs/ressources/xgboost_test.yaml"

# %% [markdown]
# # Run

# %% [markdown]
# train

# %%
train_map = {'x_train':X_train, 'y_train':y_train}
val_map = {'x_val':X_val, 'y_val':y_val}

# %%
run = XGBoostRun(train_map = train_map, val_map = val_map, config_path = config_path,test_path=config_path_test)

# %%
run.run()
# Out:
# [I 2026-06-19 02:39:13,370] A new study created in memory with name: no-name-b71908f2-e067-4d59-a81d-74965c885e85
# [I 2026-06-19 02:39:56,912] Trial 0 finished with value: 0.18470126364863207 and parameters: {'max_depth': 5, 'min_child_weight': 2, 'reg_lambda': 6.340138256178493, 'reg_alpha': 0.6678629289377119, 'subsample': 0.7165254151685007, 'colsample_bytree': 0.8770166191154309, 'learning_rate': 0.020620481625936056, 'n_estimators': 245}. Best is trial 0 with value: 0.18470126364863207.
# 0.8572041014601246
# 0.8010109071561585
# [I 2026-06-19 02:40:41,226] Trial 1 finished with value: 0.18073937928898923 and parameters: {'max_depth': 3, 'min_child_weight': 3, 'reg_lambda': 8.3414472145588, 'reg_alpha': 0.9006681761149979, 'subsample': 0.8290140346130248, 'colsample_bytree': 0.7243475546405669, 'learning_rate': 0.08838212851829826, 'n_estimators': 381}. Best is trial 0 with value: 0.18470126364863207.
# 0.8557950809218893
# 0.8022523720847743
# [I 2026-06-19 02:41:25,802] Trial 2 finished with value: 0.18135180453529223 and parameters: {'max_depth': 7, 'min_child_weight': 5, 'reg_lambda': 6.464001317474388, 'reg_alpha': 0.8254694654242474, 'subsample': 0.7903979340229087, 'colsample_bytree': 0.7028765144482465, 'learning_rate': 0.047476166087308515, 'n_estimators': 214}. Best is trial 0 with value: 0.18470126364863207.
# 0.8578419784239504
# 0.8056220626053028
# [I 2026-06-19 02:42:26,645] Trial 3 finished with value: 0.17512055120164666 and parameters: {'max_depth': 6, 'min_child_weight': 2, 'reg_lambda': 2.1603200176994006, 'reg_alpha': 0.26701361453420114, 'subsample': 0.7951867425793322, 'colsample_bytree': 0.7635154967367901, 'learning_rate': 0.08593095207388858, 'n_estimators': 445}. Best is trial 0 with value: 0.18470126364863207.
# 0.852695108258847
# 0.80349383701339
# [I 2026-06-19 02:43:11,115] Trial 4 finished with value: 0.1808865538664376 and parameters: {'max_depth': 4, 'min_child_weight': 2, 'reg_lambda': 4.851336885940584, 'reg_alpha': 0.9988605072473741, 'subsample': 0.8696125142038551, 'colsample_bytree': 0.7366267467567404, 'learning_rate': 0.04935660422710717, 'n_estimators': 337}. Best is trial 0 with value: 0.18470126364863207.
# 0.8569131454543721
# 0.8029617806154119
# [I 2026-06-19 02:44:14,790] Trial 5 finished with value: 0.18316300718405343 and parameters: {'max_depth': 7, 'min_child_weight': 1, 'reg_lambda': 7.612401695919286, 'reg_alpha': 0.09895216507324911, 'subsample': 0.8374729129387452, 'colsample_bytree': 0.7965027725089654, 'learning_rate': 0.024094143489156006, 'n_estimators': 404}. Best is trial 0 with value: 0.18470126364863207.
# 0.8582082494016439
# 0.8026070763500931
# [I 2026-06-19 02:44:47,363] Trial 6 finished with value: 0.18410526102052835 and parameters: {'max_depth': 5, 'min_child_weight': 3, 'reg_lambda': 5.520148234379827, 'reg_alpha': 0.8594052463075069, 'subsample': 0.8709274138094982, 'colsample_bytree': 0.82943593006502, 'learning_rate': 0.04735378965588235, 'n_estimators': 124}. Best is trial 0 with value: 0.18470126364863207.
# 0.8580954814131092
# 0.8040258934113683
# [I 2026-06-19 02:45:22,742] Trial 7 finished with value: 0.18049291874357148 and parameters: {'max_depth': 5, 'min_child_weight': 4, 'reg_lambda': 1.7269070653488938, 'reg_alpha': 0.9667449375055013, 'subsample': 0.7429308181816252, 'colsample_bytree': 0.746625721976713, 'learning_rate': 0.018602236648552595, 'n_estimators': 151}. Best is trial 0 with value: 0.18470126364863207.
# 0.8568060037757976
# 0.8091691052584907
# [I 2026-06-19 02:45:53,375] Trial 8 finished with value: 0.17614827842792397 and parameters: {'max_depth': 4, 'min_child_weight': 2, 'reg_lambda': 9.775513460478626, 'reg_alpha': 0.7868774460903547, 'subsample': 0.7015457810724053, 'colsample_bytree': 0.8563668293951272, 'learning_rate': 0.024766962570818056, 'n_estimators': 117}. Best is trial 0 with value: 0.18470126364863207.
# 0.8514357351118172
# 0.8081936685288641
# [I 2026-06-19 02:46:32,074] Trial 9 finished with value: 0.1806470881035341 and parameters: {'max_depth': 3, 'min_child_weight': 4, 'reg_lambda': 1.2377606908444094, 'reg_alpha': 0.8978885821254091, 'subsample': 0.8382014467866524, 'colsample_bytree': 0.7396379507308142, 'learning_rate': 0.0851205658666353, 'n_estimators': 263}. Best is trial 0 with value: 0.18470126364863207.
# 0.8566620148598189
# 0.8045579498093465
# [I 2026-06-19 02:47:37,760] Trial 10 finished with value: 0.17545150825545924 and parameters: {'max_depth': 6, 'min_child_weight': 1, 'reg_lambda': 4.162679610320297, 'reg_alpha': 0.5477733727488866, 'subsample': 0.7005832022141438, 'colsample_bytree': 0.8946606399148708, 'learning_rate': 0.06377025330822499, 'n_estimators': 500}. Best is trial 0 with value: 0.18470126364863207.
# 0.8534529571312772
# 0.8033164848807307
# [I 2026-06-19 02:48:19,300] Trial 11 finished with value: 0.1837404967055246 and parameters: {'max_depth': 5, 'min_child_weight': 3, 'reg_lambda': 5.7304499797491335, 'reg_alpha': 0.603133864792379, 'subsample': 0.8857704611675412, 'colsample_bytree': 0.8362400185737361, 'learning_rate': 0.039027302439935754, 'n_estimators': 214}. Best is trial 0 with value: 0.18470126364863207.
# 0.8584403142405578
# 0.8036711891460495
# [I 2026-06-19 02:49:08,224] Trial 12 finished with value: 0.18185822105663552 and parameters: {'max_depth': 5, 'min_child_weight': 3, 'reg_lambda': 3.4995058859675545, 'reg_alpha': 0.6353574590306896, 'subsample': 0.7560383249998943, 'colsample_bytree': 0.8470999362643573, 'learning_rate': 0.011160424409671759, 'n_estimators': 288}. Best is trial 0 with value: 0.18470126364863207.
# 0.8563755797235362
# 0.8055333865389731
# [I 2026-06-19 02:49:45,427] Trial 13 finished with value: 0.1826566031643526 and parameters: {'max_depth': 4, 'min_child_weight': 2, 'reg_lambda': 6.495974075626482, 'reg_alpha': 0.4334184302820403, 'subsample': 0.7497645518255649, 'colsample_bytree': 0.8798539219847527, 'learning_rate': 0.0653597860832135, 'n_estimators': 175}. Best is trial 0 with value: 0.18470126364863207.
# 0.8575576002152347
# 0.8026070763500931
# [I 2026-06-19 02:50:35,184] Trial 14 finished with value: 0.18390897844119497 and parameters: {'max_depth': 6, 'min_child_weight': 4, 'reg_lambda': 8.133886966332996, 'reg_alpha': 0.7250772543812085, 'subsample': 0.7923341394161745, 'colsample_bytree': 0.8142617838070494, 'learning_rate': 0.03530385050262272, 'n_estimators': 280}. Best is trial 0 with value: 0.18470126364863207.
# 0.8590390543223332
# 0.804114569477698
# 🏃 View run Xgboost Train at: http://localhost:5000/#/experiments/1/runs/7b18ab9b5bfb4b25b449326a46f124bf
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %%
X_val.shape
# Out:
# (333833, 20)

# %%
y_val.shape
# Out:
# (333833,)

# %%
y_val.value_counts()
# Out:
# default
# 0    322556
# 1     11277
# Name: count, dtype: int64

# %% [markdown]
# test

# %%
config_path ="/Users/macbookpro/platform/Backend/configs/ressources/xgboost_test.yaml"

# %%
test_map = {'x_test':X_test, 'y_test':y_test}

# %%
run = XGBoostRun(test_map = test_map, config_path = config_path)

# %%
run.run()
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts: 100%|██████████| 1/1 [00:00<00:00, 17.65it/s]
# Downloading artifacts: 100%|██████████| 1/1 [00:00<00:00,  9.17it/s]
# 🏃 View run Xgboost test at: http://localhost:5000/#/experiments/1/runs/b1f9fd613e624f79b1a55363cee41196
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
