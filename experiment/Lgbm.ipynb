# %%
import numpy as np
import pandas as frame

import importlib

import pandas as pd

import src.PDcomponent.run.ligthGBMRUN as lGBM
importlib.reload(lGBM)

from src.PDcomponent.run.ligthGBMRUN import LightGBMRun
from src.PDcomponent.pipelines.pdFeaturePipeline import PDFeaturePipeline

# %% [markdown]
# # Get DATA

# %%
orig = frame.read_csv('/Users/macbookpro/platform/Backend/data/working/origination_v02.csv')
# Out:
# /var/folders/gy/2mbpv0kx5jz22fry28cqlnkc0000gn/T/ipykernel_21830/3542022219.py:1: DtypeWarning: Columns (25,26,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   orig = frame.read_csv('/Users/macbookpro/platform/Backend/data/working/origination_v02.csv')

# %%
hist  = frame.read_csv('/Users/macbookpro/platform/Backend/data/working/hist_12m.csv')
# Out:
# /var/folders/gy/2mbpv0kx5jz22fry28cqlnkc0000gn/T/ipykernel_21830/2861163649.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   hist  = frame.read_csv('/Users/macbookpro/platform/Backend/data/working/hist_12m.csv')

# %%
pipeline = PDFeaturePipeline(window_months=12, woe_config={"iv_threshold": 0.01, "metric": "woe"})
X,y = pipeline.build(hist, orig)
# Out:
# Copy DataFrame     : 9.1s
# Cast DPD           : 7.3s
# Groupby            : 0.0s
# Colonnes de travail: 13.2s

# %%
X_train = pd.read_csv('/Users/macbookpro/platform/Backend/data/processed/x_train.csv', sep=',')
y_train = pd.read_csv('/Users/macbookpro/platform/Backend/data/processed/y_train.csv', sep=',').squeeze()
X_val = pd.read_csv('/Users/macbookpro/platform/Backend/data/processed/x_val.csv', sep=',')
y_val = pd.read_csv('/Users/macbookpro/platform/Backend/data/processed/y_val.csv', sep=',').squeeze()

# %%
X_test = pd.read_csv('/Users/macbookpro/platform/Backend/data/processed/x_test.csv', sep=',')
y_test = pd.read_csv('/Users/macbookpro/platform/Backend/data/processed/y_test.csv', sep=',').squeeze()

# %% [markdown]
# # Config

# %%
config_path = '/Users/macbookpro/platform/Backend/configs/ressources/Lgbm.yaml'

# %% [markdown]
# # RUN

# %% [markdown]
#         - TRAIN

# %%
train_map = {'x_train':X_train, 'y_train':y_train}
val_map = {'x_val':X_val, 'y_val':y_val}

# %%
run = LightGBMRun(train_map = train_map, val_map = val_map, config_path = config_path)

# %%
run.run()
# Out:
# [LightGBM] [Warning] early_stopping_round is set=10, early_stopping_rounds=10 will be ignored. Current value: early_stopping_round=10
# [LightGBM] [Info] Number of positive: 753222, number of negative: 753222
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.039086 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2084
# [LightGBM] [Info] Number of data points in the train set: 1506444, number of used features: 10
# [LightGBM] [Warning] early_stopping_round is set=10, early_stopping_rounds=10 will be ignored. Current value: early_stopping_round=10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Did not meet early stopping. Best iteration is:
# [100]	valid_0's binary_logloss: 0.376077
# /Users/macbookpro/platform/Backend/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/macbookpro/platform/Backend/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/macbookpro/platform/Backend/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/macbookpro/platform/Backend/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/macbookpro/platform/Backend/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Users/macbookpro/platform/Backend/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# {'recall': np.float64(0.9029883834353108), 'precision': np.float64(0.07770909645909646), 'f1': np.float64(0.14310307271794656), 'pred': array([0, 1, 1, ..., 0, 0, 1], shape=(333833,)), 'threshold': np.float64(0.2599999999999999)}
# 🏃 View run lightgbm Train at: http://localhost:5000/#/experiments/1/runs/19913faf608341c8a96aa199ca019445
# 🧪 View experiment at: http://localhost:5000/#/experiments/1

# %% [markdown]
#         - TEST
