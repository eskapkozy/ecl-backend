# %%
import numpy as np
import pandas as frame

import importlib

import pandas as pd

import src.PDcomponent.run.logistiqueRegressionTrainRun as LogistiqueRegressionTrainRun
importlib.reload(LogistiqueRegressionTrainRun)

from src.PDcomponent.run.logistiqueRegressionTrainRun import LogistiqueRegressionTrainRun
from src.PDcomponent.pipelines.pdFeaturePipeline import PDFeaturePipeline

# %%
orig = frame.read_csv('/Users/macbookpro/platform/Backend/data/working/origination_v02.csv')
# Out:
# /var/folders/gy/2mbpv0kx5jz22fry28cqlnkc0000gn/T/ipykernel_7628/3542022219.py:1: DtypeWarning: Columns (25,26,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   orig = frame.read_csv('/Users/macbookpro/platform/Backend/data/working/origination_v02.csv')

# %%
hist  = frame.read_csv('/Users/macbookpro/platform/Backend/data/working/hist_12m.csv')
# Out:
# /var/folders/gy/2mbpv0kx5jz22fry28cqlnkc0000gn/T/ipykernel_7628/2861163649.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   hist  = frame.read_csv('/Users/macbookpro/platform/Backend/data/working/hist_12m.csv')

# %%
pipeline = PDFeaturePipeline(window_months=12, woe_config={"iv_threshold": 0.01, "metric": "woe"})
X,y = pipeline.build(hist, orig)
# Out:
# Copy DataFrame     : 6.6s
# Cast DPD           : 7.8s
# Groupby            : 0.0s
# Colonnes de travail: 8.6s

# %%
frame.Series(y).value_counts()
# Out:
# default
# 0    1344626
# 1      46344
# Name: count, dtype: int64

# %% [markdown]
# # SPLIT

# %%
from sklearn.model_selection import train_test_split

# 1. Separate the full dataset into Training (80%) and a temporary Test set (20%)
X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# 2. Split the temp set into Training (70%) and Validation (30% of the temp set, or 15% of the total)
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.30, random_state=42)

# %% [markdown]
# # Config

# %%
config_path = '/Users/macbookpro/platform/Backend/configs/ressources/Logistic_train.yaml'

# %% [markdown]
# # RUN

# %%
train_map = {'x_train':X_train, 'y_train':y_train}
val_map = {'x_val':X_val, 'y_val':y_val}

# %%
run = LogistiqueRegressionTrainRun(train_map = train_map, val_map = val_map, config_path = config_path)

# %%
run.run()
# Out:
# /Users/macbookpro/platform/Backend/.venv/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# {'recall': np.float64(0.9002394253790902), 'precision': np.float64(0.069885589194994), 'f1': np.float64(0.12970238209309903), 'pred': array([0, 1, 0, ..., 0, 0, 1], shape=(333833,)), 'threshold': np.float64(0.33999999999999986)}
# 🏃 View run Logistic regression Train at: http://localhost:5000/#/experiments/1/runs/8f9186e65a0f4972b9b71d9bc4459f15
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
