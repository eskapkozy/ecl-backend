# %% [markdown]
# # Get Data

# %%
import pandas as pd

# %% [markdown]
# F07Q10000005  F07Q10308393 F07Q10308424

# %%
import pandas as pd
from src.api.warehouse.warehouseLoader import WarehouseLoader, WarehouseReader

HIST_PATH = "/Users/macbookpro/platform/Backend/data/processed/hist_12m.csv"
ORIG_PATH = "/Users/macbookpro/platform/Backend/data/raw/orig_data_col.csv"

DB_URL    = "postgresql://warehouse_user:warehouse_eskap@localhost:5433/warehouse"
DB_PARAMS = {
    "host": "localhost", "port": 5433,
    "dbname": "warehouse",
    "user": "warehouse_user",
    "password": "warehouse_eskap"
}

# %%
hist = pd.read_csv(HIST_PATH, parse_dates=["MONTHLY_REPORTING_PERIOD"])
orig = pd.read_csv(ORIG_PATH)
# Out:
# /var/folders/gy/2mbpv0kx5jz22fry28cqlnkc0000gn/T/ipykernel_53165/898379605.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   hist = pd.read_csv(HIST_PATH, parse_dates=["MONTHLY_REPORTING_PERIOD"])
# /var/folders/gy/2mbpv0kx5jz22fry28cqlnkc0000gn/T/ipykernel_53165/898379605.py:2: DtypeWarning: Columns (24,25,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   orig = pd.read_csv(ORIG_PATH)

# %%
WarehouseLoader(db_url=DB_URL, db_params=DB_PARAMS)#.load(hist, orig)

# %%
orig['CREDIT_SCORE'].unique()
# Out:
# array([706., 615., 681., 687., 813., 776., 644., 757., 571., 784., 800.,
#        662., 742., 704., 728., 745., 598., 661., 606., 778., 700., 769.,
#        722., 717., 770., 734., 675., 775., 665., 712., 744., 684., 766.,
#        691., 790., 804., 758., 659., 764., 698., 655., 812., 629., 679.,
#        785., 753., 664., 713., 819., 685., 795., 588., 799., 611., 709.,
#        815., 726., 616., 737., 718., 651., 760., 773., 801., 648., 647.,
#        793., 759., 697., 640., 686., 777., 761., 809., 746., 747., 694.,
#        732., 710., 816., 682., 645., 721., 772., 810., 762., 748., 783.,
#        730., 797., 639., 733., 719., 803., 714., 579., 676., 672., 735.,
#        628., 692., 601., 703., 806., 791., 768., 695., 646., 649., 802.,
#        654., 699., 696., 771., 683., 680., 716., 786., 798., 741., 792.,
#        788., 652., 590., 817., 765., 751., 796., 789., 693., 689., 750.,
#        736., 823., 754., 725., 670., 627., 671., 581., 780., 782., 756.,
#        666., 643., 752., 605., 669., 805., 720., 774., 641., 723., 739.,
#        701., 787., 705., 811., 702., 727., 807., 808., 602., 763., 624.,
#        593., 708., 724., 711., 677., 635., 749., 660., 707., 586., 781.,
#        650., 596., 767., 779., 658., 729., 619., 688., 607., 613., 524.,
#        656., 667., 731., 678., 743., 623., 740., 642., 620., 674., 657.,
#        738., 715., 755., 653., 603., 625., 794., 636., 617., 577., 626.,
#        814., 622., 556., 818., 690., 630., 673., 584., 634., 612., 618.,
#        633., 668., 637., 595., 547., 632., 562., 585., 583., 638., 631.,
#        663., 557., 610., 609., 591., 608., 592., 599., 604., 566., 573.,
#        600., 820., 558., 614., 621., 597., 576., 572., 539., 530., 574.,
#        582., 587., 546., 594., 578., 589., 580., 568., 555., 825., 827.,
#        533., 536., 526., 508., 502., 534., 554., 565., 543., 563., 523.,
#        559., 483., 570., 492., 538., 850., 552., 824., 821., 541., 561.,
#        564., 525., 569., 512., 567., 531., 545., 509., 506., 560., 300.,
#        513., 529., 550., 544., 540., 501., 575., 528., 535., 522., 549.,
#        548., 553., 537., 831., 826., 517., 551., 500., 822., 400., 518.,
#        478., 521., 829., 507., 494., 488., 486., 490., 532., 461., 542.,
#        527., 516., 519., 830., 510., 468., 832., 504., 497., 520., 511.,
#        515., 487., 493., 834., 833., 479., 514., 836., 840., 402., 837.,
#        354., 828., 484., 481., 505., 835., 839., 843., 842., 476., 489.,
#        499., 482., 441., 480., 491., 503., 469., 471., 477., 495., 464.,
#        427., 498., 485., 467., 455., 496., 456., 459., 463., 454., 423.,
#        465., 460., 474., 473., 451., 466., 453., 470., 439., 442., 838.])

# %%
orig.columns.tolist()
# Out:
# ['CREDIT_SCORE',
#  'FIRST_TIME_HOMEBUYER_FLAG',
#  'MSA',
#  'MI_PERCENTAGE',
#  'NUMBER_OF_UNITS',
#  'OCCUPANCY_STATUS',
#  'OCLTV',
#  'DTI',
#  'ORIGINAL_UPB',
#  'LTV',
#  'ORIGINAL_INTEREST_RATE',
#  'CHANNEL',
#  'PPM_FLAG',
#  'PRODUCT_TYPE',
#  'STATE',
#  'PROPERTY_TYPE',
#  'POSTAL_CODE',
#  'LOAN_SEQUENCE_NUMBER',
#  'LOAN_PURPOSE',
#  'ORIGINAL_LOAN_TERM',
#  'NUMBER_OF_BORROWERS',
#  'SELLER_NAME',
#  'SERVICER_NAME',
#  'SUPER_CONFORMING_FLAG',
#  'PRE_RELIEF_REFI_LOAN_SEQ',
#  'PROGRAM_INDICATOR',
#  'RELIEF_REFINANCE_INDICATOR',
#  'PROPERTY_VALUATION_METHOD',
#  'IO_FLAG',
#  'MORTGAGE_INSURANCE_CANCELLATION',
#  'IS_MISSING_CREDIT_SCORE',
#  'IS_MISSING_DTI']

# %%
with WarehouseReader(db_url=DB_URL).engine.connect() as conn:
    print(pd.read_sql("SELECT COUNT(*) FROM loans_performance", conn))
    print(pd.read_sql("SELECT COUNT(*) FROM loans_origination", conn))
    print(pd.read_sql("SELECT * FROM loans_performance LIMIT 3", conn))
    print(pd.read_sql("SELECT * FROM loans_origination LIMIT 3", conn))
# Out:
#       count
# 0  15041114
#      count
# 0  1390970
#   loan_sequence_number monthly_reporting_period  current_actual_upb  \
# 0         F07Q10000001               2007-05-01            168000.0
# 1         F07Q10000001               2007-06-01            168000.0
# 2         F07Q10000001               2007-07-01            168000.0
#
#   current_loan_delinquency_status  loan_age  \
# 0                               0         1
# 1                               0         2
# 2                               0         3
#
#    remaining_months_to_legal_maturity modification_flag  zero_balance_code  \
# 0                               239.0                 N                  0
# 1                               238.0                 N                  0
# 2                               237.0                 N                  0
#
#   zero_balance_effective_date  current_interest_rate  \
# 0                        None                  7.375
# 1                        None                  7.375
# 2                        None                  7.375
#
#    current_non_interest_bearing_upb due_date_of_last_paid_installment  \
# 0                               0.0                              None
# 1                               0.0                              None
# 2                               0.0                              None
#
#   interest_rate_step_indicator  estimated_ltv delinquency_due_to_disaster  \
# 0                            N          74.56                           N
# 1                            N          74.56                           N
# 2                            N          74.56                           N
#
#   borrower_assistance_status_code  interest_bearing_upb
# 0                               N              168000.0
# 1                               N              168000.0
# 2                               N              168000.0
#   loan_sequence_number  credit_score first_time_homebuyer_flag      msa  \
# 0         F07Q10000001         706.0                         N  20260.0
# 1         F07Q10000002         615.0                         N  36980.0
# 2         F07Q10000003         681.0                         Y  48424.0
#
#    mi_percentage  number_of_units occupancy_status  ocltv   dti  original_upb  \
# 0            0.0                2                I   75.0  36.0      169000.0
# 1            0.0                1                P   61.0  38.0       28000.0
# 2           30.0                1                P   95.0  46.0      271000.0
#
#    ...    servicer_name  super_conforming_flag pre_relief_refi_loan_seq  \
# 0  ...  Other servicers                      N                     None
# 1  ...  Other servicers                      N                     None
# 2  ...  Other servicers                      N                     None
#
#   program_indicator relief_refinance_indicator property_valuation_method  \
# 0                 9                          N                         7
# 1                 9                          N                         7
# 2                 9                          N                         7
#
#   io_flag mortgage_insurance_cancellation is_missing_credit_score  \
# 0       N                               9                       0
# 1       N                               9                       0
# 2       N                               9                       0
#
#    is_missing_dti
# 0               0
# 1               0
# 2               0
#
# [3 rows x 32 columns]
